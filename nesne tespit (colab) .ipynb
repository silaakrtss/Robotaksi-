# %% [markdown]
# <a href="https://colab.research.google.com/github/silaakrtss/Robotaksi-/blob/master/nesne%20tespit%20(colab)%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 13.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import cv2
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 77.0MB/s]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e66095a7-7711-4de3-9784-2126ffdc3642" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e66095a7-7711-4de3-9784-2126ffdc3642">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded_image = '/content/ışık.jpg'

# %%
results = model(uploaded_image, conf=0.5)
# Out:
# image 1/1 /content/ışık.jpg: 448x640 2 traffic lights, 394.7ms
# Speed: 17.8ms preprocess, 394.7ms inference, 36.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
results[0].plot(show=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1363>
# array([[[248, 248, 248],
#         [248, 248, 248],
#         [248, 248, 248],
#         ...,
#         [ 99,  99,  99],
#         [ 99,  99,  99],
#         [ 99,  99,  99]],
#
#        [[248, 248, 248],
#         [248, 248, 248],
#         [248, 248, 248],
#         ...,
#         [ 99,  99,  99],
#         [ 99,  99,  99],
#         [ 99,  99,  99]],
#
#        [[248, 248, 248],
#         [248, 248, 248],
#         [248, 248, 248],
#         ...,
#         [ 98,  98,  98],
#         [ 98,  98,  98],
#         [ 99,  99,  99]],
#
#        ...,
#
#        [[ 91,  91,  91],
#         [ 91,  91,  91],
#         [ 90,  90,  90],
#         ...,
#         [101, 101, 101],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[ 91,  91,  91],
#         [ 91,  91,  91],
#         [ 90,  90,  90],
#         ...,
#         [101, 101, 101],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[ 91,  91,  91],
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Bilgisayarınızdan dosya seçmenizi isteyecektir
# Out:
#      <input type="file" id="files-622cdb5e-f45a-4cfb-8983-342693a15af3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-622cdb5e-f45a-4cfb-8983-342693a15af3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded_image = '/content/dur.jpg'

# %%
results = model(uploaded_image, conf=0.5)
# Out:
# image 1/1 /content/dur.jpg: 320x640 1 car, 1 stop sign, 144.9ms
# Speed: 7.1ms preprocess, 144.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)

# %%
results[0].plot(show=True)
# Out:
# <PIL.Image.Image image mode=RGB size=620x310>
# array([[[ 36,  61,  35],
#         [ 18,  42,  18],
#         [ 16,  37,  15],
#         ...,
#         [217, 214, 206],
#         [215, 212, 204],
#         [213, 210, 202]],
#
#        [[ 33,  57,  33],
#         [ 15,  39,  15],
#         [ 14,  35,  13],
#         ...,
#         [217, 214, 206],
#         [214, 211, 203],
#         [213, 210, 202]],
#
#        [[ 42,  63,  41],
#         [ 25,  46,  24],
#         [ 21,  41,  22],
#         ...,
#         [215, 212, 204],
#         [213, 210, 202],
#         [212, 209, 201]],
#
#        ...,
#
#        [[115, 114, 116],
#         [109, 108, 110],
#         [108, 107, 109],
#         ...,
#         [113, 120, 115],
#         [112, 119, 114],
#         [110, 117, 112]],
#
#        [[115, 114, 116],
#         [108, 107, 109],
#         [107, 106, 108],
#         ...,
#         [114, 121, 116],
#         [113, 120, 115],
#         [111, 118, 113]],
#
#        [[113, 112, 114],
# ...
